# %% [markdown]
# # Google (GOOG):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - Google:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/google_quandle.csv')
df.head()
# Out:
#          Date  WIKI/GOOGL - Open  WIKI/GOOGL - High  WIKI/GOOGL - Low  \
# 0  2004-08-19             100.01             104.06             95.96
# 1  2004-08-20             101.01             109.08            100.50
# 2  2004-08-23             110.76             113.48            109.05
# 3  2004-08-24             111.24             111.60            103.57
# 4  2004-08-25             104.76             108.00            103.88
#
#    WIKI/GOOGL - Close  WIKI/GOOGL - Volume  WIKI/GOOGL - Ex-Dividend  \
# 0             100.335           44659000.0                       0.0
# 1             108.310           22834300.0                       0.0
# 2             109.400           18256100.0                       0.0
# 3             104.870           15247300.0                       0.0
# 4             106.000            9188600.0                       0.0
#
#    WIKI/GOOGL - Split Ratio  WIKI/GOOGL - Adj. Open  WIKI/GOOGL - Adj. High  \
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Google's Stock:

# %%
google = Stock('GOOGL')

# %%
print('Current Price:', google.get_price())
print('06/15/2018 Opening Price:', google.get_open())
print('06/15/2018 Closing Price:', google.get_close())
# Out:
# Current Price: 1159.27
# 06/15/2018 Opening Price: 1159.92
# 06/15/2018 Closing Price: 1159.27

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

google_df = get_historical_data("GOOGL", start=start, end=end, output_format='pandas')
google_df.head(10)
# Out:
#                 open      high       low     close   volume
# date
# 2013-06-17  440.0546  445.1597  439.5791  443.5681  4287768
# 2013-06-18  444.7693  450.9505  444.6192  450.7603  4329191
# 2013-06-19  451.1357  455.8754  449.1988  450.7903  5825958
# 2013-06-20  447.4420  450.9505  442.0967  442.8124  6737253
# 2013-06-21  444.6142  445.3849  436.9715  440.9055  7956472
# 2013-06-24  436.3759  438.5982  432.0566  435.3299  6027497
# 2013-06-25  439.0686  440.2798  432.6873  433.5331  5101271
# 2013-06-26  437.3119  439.4390  435.7203  437.2618  3658997
# 2013-06-27  439.8394  442.7873  438.7633  438.9735  3849059
# 2013-06-28  437.8875  441.3609  437.5326  440.6252  4693361

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('GOOGL')
financials.T
# Out:
#                                    0             1             2             3
# cashChange                1778000000     116000000   -5238000000   -2509000000
# cashFlow                 11642000000   10268000000    9872000000    7403000000
# costOfRevenue            13467000000   14267000000   11148000000   10373000000
# currentAssets           123761000000  124308000000  119345000000  112386000000
# currentCash              12658000000   10715000000   10581000000   15711000000
# currentDebt                1.329e+09           NaN           NaN           NaN
# grossProfit              17679000000   18056000000   16624000000   15637000000
# netIncome                 9401000000   -3020000000    6732000000    3524000000
# operatingExpense         10678000000   10392000000    8842000000    8769000000
# operatingGainsLosses     -2992000000      34000000      76000000      65000000
# operatingIncome           7001000000    7664000000    7782000000    6868000000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('GOOGL')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-23  2018-02-01  2017-10-26  2017-07-24
# EPSSurpriseDollar             0.72       -0.42        1.14        0.62
# actualEPS                     9.93         9.7        9.57        5.01
# announceTime                   AMC         AMC         AMC         AMC
# consensusEPS                  9.21       10.12        8.43        4.39
# estimatedChangePercent    0.191462    0.338624    0.162759   -0.372857
# estimatedEPS                  9.21       10.12        8.43        4.39
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates               13          14          17          11
# symbolId                     10657       10657       10657       10657
# yearAgo                       7.73        7.56        7.25           7
# ...

# %%
iex.get_chart('GOOGL', chart_range='5y')
# Out:
#          change  changeOverTime  changePercent      close        date  \
# 0      5.610600        0.000000          1.281   443.5681  2013-06-17
# 1      7.192200        0.016214          1.621   450.7603  2013-06-18
# 2      0.030030        0.016282          0.007   450.7903  2013-06-19
# 3     -7.978000       -0.001704         -1.770   442.8124  2013-06-20
# 4     -1.906900       -0.006003         -0.431   440.9055  2013-06-21
# 5     -5.575600       -0.018573         -1.265   435.3299  2013-06-24
# 6     -1.796800       -0.022623         -0.413   433.5331  2013-06-25
# 7      3.728700       -0.014217          0.860   437.2618  2013-06-26
# 8      1.711700       -0.010358          0.391   438.9735  2013-06-27
# 9      1.651600       -0.006635          0.376   440.6252  2013-06-28
# 10     3.758800        0.001839          0.853   444.3839  2013-07-01
# 11    -2.787800       -0.004446         -0.627   441.5962  2013-07-02
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('GOOGL'))
iex.get_quote('GOOGL')
# Out:
# {'symbol': 'GOOGL', 'delayedPrice': 1159.27, 'high': 1163.909, 'low': 1153.69, 'delayedSize': 356727, 'delayedPriceTime': 1529092800490, 'processedTime': 1529093701006}
# {'symbol': 'GOOGL',
#  'companyName': 'Alphabet Inc.',
#  'primaryExchange': 'Nasdaq Global Select',
#  'sector': 'Technology',
#  'calculationPrice': 'close',
#  'open': 1159.92,
#  'openTime': 1529069400741,
#  'close': 1159.27,
#  'closeTime': 1529092800490,
#  'high': 1163.909,
#  'low': 1153.69,
#  'latestPrice': 1159.27,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092800490,
#  'latestVolume': 2162151,
#  'iexRealtimePrice': 1159.25,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1529092799901,
#  'delayedPrice': 1159.27,
#  'delayedPriceTime': 1529092800490,
#  'extendedPrice': 1159.3,
#  'extendedChange': 0.03,
#  'extendedChangePercent': 3e-05,
#  'extendedPriceTime': 1529096370987,
#  'previousClose': 1160.11,
#  'change': -0.84,
#  'changePercent': -0.00072,
# ...

# %%
iex.get_effective_spread('GOOGL')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.839796         0.475473          0.052364  XCHI            CHX
# 1          0.725551         0.354695          0.084232  XPHL     Nasdaq PSX
# 2          0.880346         0.316727          0.033251  XASE  NYSE American
# 3          0.753807         0.304354          0.075636  XNYS           NYSE
# 4          0.645739         0.304035          0.098014  BATY       Cboe BYX
# 5          0.681487         0.299712          0.092928  XNGS         Nasdaq
# 6          0.699947         0.297866          0.092912  XBOS      Nasdaq BX
# 7          0.969739         0.294594          0.010330  XCIS  NYSE National
# 8          0.627604         0.290454          0.108699  BATS       Cboe BZX
# 9          0.712717         0.282923          0.081141  ARCX      NYSE Arca
# 10         0.618326         0.278203          0.105503  EDGA      Cboe EDGA
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('GOOGL').T
# Out:
#                                  0
# EBITDA                 25870000000
# EPSSurpriseDollar             None
# EPSSurprisePercent          7.8176
# beta                       1.08347
# cash                  296727000000
# companyName          Alphabet Inc.
# consensusEPS                  9.21
# day200MovingAvg            1057.38
# day30ChangePercent        0.103016
# day50MovingAvg             1079.96
# day5ChangePercent        0.0161013
# debt                             0
# dividendRate                     0
# dividendYield                    0
# exDividendDate                   0
# float                    673923008
# grossProfit            50317000000
# insiderPercent                None
# institutionPercent            29.7
# latestEPS                        0
# latestEPSDate           2017-12-31
# marketcap             805169544483
# month1ChangePercent      0.0685796
# month3ChangePercent     0.00752644
# month6ChangePercent      0.0814086
# numberOfEstimates               13
# ...
