# %% [markdown]
# # Microsoft (MSFT):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - Microsoft:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/microsoft_quandle.csv')
df.head()
# Out:
#          Date  WIKI/MSFT - Open  WIKI/MSFT - High  WIKI/MSFT - Low  \
# 0  1986-03-13             25.50             29.25             25.5
# 1  1986-03-14             28.00             29.50             28.0
# 2  1986-03-17             29.00             29.75             29.0
# 3  1986-03-18             29.50             29.75             28.5
# 4  1986-03-19             28.75             29.00             28.0
#
#    WIKI/MSFT - Close  WIKI/MSFT - Volume  WIKI/MSFT - Ex-Dividend  \
# 0              28.00           3582600.0                      0.0
# 1              29.00           1070000.0                      0.0
# 2              29.50            462400.0                      0.0
# 3              28.75            235300.0                      0.0
# 4              28.25            166300.0                      0.0
#
#    WIKI/MSFT - Split Ratio  WIKI/MSFT - Adj. Open  WIKI/MSFT - Adj. High  \
# 0                      1.0               0.058941               0.067609
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Microsoft's Stock:

# %%
msft = Stock('MSFT')

# %%
print('Current Price:', msft.get_price())
print('06/15/2018 Opening Price:', msft.get_open())
print('06/15/2018 Closing Price:', msft.get_close())
# Out:
# Current Price: 100.13
# 06/15/2018 Opening Price: 101.52
# 06/15/2018 Closing Price: 100.13

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

msft_df = get_historical_data("MSFT", start=start, end=end, output_format='pandas')
msft_df.head(10)
# Out:
#                open     high      low    close    volume
# date
# 2013-06-17  30.5644  30.9785  30.5115  30.8375  49670032
# 2013-06-18  30.8111  30.9873  30.7450  30.8199  28614869
# 2013-06-19  30.8023  30.9168  30.4763  30.4763  30816008
# 2013-06-20  30.1855  30.2472  29.4013  29.5071  54493643
# 2013-06-21  29.6569  29.7185  29.1194  29.3088  85337340
# 2013-06-24  29.0225  30.1326  28.6965  29.7053  56108988
# 2013-06-25  30.0269  30.2912  29.4806  29.6657  44051085
# 2013-06-26  30.0621  30.3793  29.8573  30.2648  48665592
# 2013-06-27  30.4146  30.6437  30.3970  30.5027  28993042
# 2013-06-28  30.2912  30.6525  30.2560  30.4366  65545445

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('MSFT')
financials.T
# Out:
#                                    0             1             2             3
# cashChange               -3663000000    5992000000    -805000000     935000000
# cashFlow                 12151000000    7875000000   12440000000   11005000000
# costOfRevenue             9269000000   11064000000    8278000000    8456000000
# currentAssets           156659000000  167633000000  161031000000  159851000000
# currentCash               9221000000   12859000000    6884000000    7663000000
# currentDebt               3677000000   15912000000    9220000000   10121000000
# grossProfit              17550000000   17854000000   16260000000   10528000000
# netIncome                 7424000000   -6302000000    6576000000    3784000000
# operatingExpense          9258000000    9175000000    8552000000    9239000000
# operatingGainsLosses      -347000000   -1749000000   -2329000000   12385000000
# operatingIncome           8292000000    8679000000    7708000000    1289000000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('MSFT')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-26  2018-01-31  2017-10-26  2017-07-20
# EPSSurpriseDollar              0.1         0.1        0.12        0.27
# actualEPS                     0.95        0.96        0.84        0.98
# announceTime                   AMC         AMC         AMC         AMC
# consensusEPS                  0.85        0.86        0.72        0.71
# estimatedChangePercent    0.164384   0.0361446  -0.0526316   0.0289855
# estimatedEPS                  0.85        0.86        0.72        0.71
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q3 2018     Q2 2018     Q1 2018     Q4 2017
# numberOfEstimates               14          14          14          14
# symbolId                      4563        4563        4563        4563
# yearAgo                       0.73        0.83        0.76        0.69
# ...

# %%
iex.get_chart('MSFT', chart_range='5y')
# Out:
#         change  changeOverTime  changePercent     close        date      high  \
# 0     0.528641        0.000000          1.744   30.8375  2013-06-17   30.9785
# 1    -0.017617       -0.000571         -0.057   30.8199  2013-06-18   30.9873
# 2    -0.343620       -0.011713         -1.115   30.4763  2013-06-19   30.9168
# 3    -0.969179       -0.043142         -3.180   29.5071  2013-06-20   30.2472
# 4    -0.198239       -0.049573         -0.672   29.3088  2013-06-21   29.7185
# 5     0.396482       -0.036715          1.353   29.7053  2013-06-24   30.1326
# 6    -0.039649       -0.037999         -0.133   29.6657  2013-06-25   30.2912
# 7     0.599128       -0.018572          2.020   30.2648  2013-06-26   30.3793
# 8     0.237891       -0.010857          0.786   30.5027  2013-06-27   30.6437
# 9    -0.066083       -0.013000         -0.217   30.4366  2013-06-28   30.6525
# 10   -0.162996       -0.018286         -0.536   30.2736  2013-07-01   30.8287
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('MSFT'))
iex.get_quote('MSFT')
# Out:
# {'symbol': 'GOOGL', 'delayedPrice': 1159.27, 'high': 1163.909, 'low': 1153.69, 'delayedSize': 356727, 'delayedPriceTime': 1529092800490, 'processedTime': 1529093701006}
# {'symbol': 'GOOGL',
#  'companyName': 'Alphabet Inc.',
#  'primaryExchange': 'Nasdaq Global Select',
#  'sector': 'Technology',
#  'calculationPrice': 'close',
#  'open': 1159.92,
#  'openTime': 1529069400741,
#  'close': 1159.27,
#  'closeTime': 1529092800490,
#  'high': 1163.909,
#  'low': 1153.69,
#  'latestPrice': 1159.27,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092800490,
#  'latestVolume': 2162151,
#  'iexRealtimePrice': 1159.25,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1529092799901,
#  'delayedPrice': 1159.27,
#  'delayedPriceTime': 1529092800490,
#  'extendedPrice': 1159.3,
#  'extendedChange': 0.03,
#  'extendedChangePercent': 3e-05,
#  'extendedPriceTime': 1529096370987,
#  'previousClose': 1160.11,
#  'change': -0.84,
#  'changePercent': -0.00072,
# ...

# %%
iex.get_effective_spread('MSFT')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.839796         0.475473          0.052364  XCHI            CHX
# 1          0.725551         0.354695          0.084232  XPHL     Nasdaq PSX
# 2          0.880346         0.316727          0.033251  XASE  NYSE American
# 3          0.753807         0.304354          0.075636  XNYS           NYSE
# 4          0.645739         0.304035          0.098014  BATY       Cboe BYX
# 5          0.681487         0.299712          0.092928  XNGS         Nasdaq
# 6          0.699947         0.297866          0.092912  XBOS      Nasdaq BX
# 7          0.969739         0.294594          0.010330  XCIS  NYSE National
# 8          0.627604         0.290454          0.108699  BATS       Cboe BZX
# 9          0.712717         0.282923          0.081141  ARCX      NYSE Arca
# 10         0.618326         0.278203          0.105503  EDGA      Cboe EDGA
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('GOOGL').T
# Out:
#                                  0
# EBITDA                 25870000000
# EPSSurpriseDollar             None
# EPSSurprisePercent          7.8176
# beta                       1.08347
# cash                  296727000000
# companyName          Alphabet Inc.
# consensusEPS                  9.21
# day200MovingAvg            1057.38
# day30ChangePercent        0.103016
# day50MovingAvg             1079.96
# day5ChangePercent        0.0161013
# debt                             0
# dividendRate                     0
# dividendYield                    0
# exDividendDate                   0
# float                    673923008
# grossProfit            50317000000
# insiderPercent                None
# institutionPercent            29.7
# latestEPS                        0
# latestEPSDate           2017-12-31
# marketcap             805169544483
# month1ChangePercent      0.0685796
# month3ChangePercent     0.00752644
# month6ChangePercent      0.0814086
# numberOfEstimates               13
# ...
