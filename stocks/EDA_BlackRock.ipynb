# %% [markdown]
# # BlackRock (BLK):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - BlackRock:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/blackrock_quandle.csv')
df.head()
# Out:
#          Date  WIKI/BLK - Open  WIKI/BLK - High  WIKI/BLK - Low  \
# 0  1999-10-01            14.00            14.25           14.00
# 1  1999-10-04            14.00            14.13           14.00
# 2  1999-10-05            14.06            14.19           14.00
# 3  1999-10-06            14.13            14.88           14.13
# 4  1999-10-07            14.88            14.88           14.06
#
#    WIKI/BLK - Close  WIKI/BLK - Volume  WIKI/BLK - Ex-Dividend  \
# 0             14.13          3162400.0                     0.0
# 1             14.06           533400.0                     0.0
# 2             14.19           270600.0                     0.0
# 3             14.88           205400.0                     0.0
# 4             14.13           214200.0                     0.0
#
#    WIKI/BLK - Split Ratio  WIKI/BLK - Adj. Open  WIKI/BLK - Adj. High  \
# 0                     1.0             10.216910             10.399354
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for BlackRock's Stock:

# %%
black = Stock('BLK')

# %%
print('Current Price:', black.get_price())
print('06/15/2018 Opening Price:', black.get_open())
print('06/15/2018 Closing Price:', black.get_close())
# Out:
# Current Price: 524.52
# 06/15/2018 Opening Price: 520.82
# 06/15/2018 Closing Price: 524.52

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

black_df = get_historical_data("BLK", start=start, end=end, output_format='pandas')
black_df.head(10)
# Out:
#                 open      high       low     close   volume
# date
# 2013-06-17  241.6454  246.5393  240.2624  244.6864   762654
# 2013-06-18  245.9187  247.6476  243.6048  245.1297   506428
# 2013-06-19  245.4843  246.6545  237.8066  238.0105   832063
# 2013-06-20  234.6947  235.7586  222.1319  223.4263  2373379
# 2013-06-21  229.1890  229.3132  214.5428  220.4651  2622578
# 2013-06-24  218.4437  220.1371  213.3104  217.7699  1564392
# 2013-06-25  221.2985  225.0753  219.5608  223.9316  1258714
# 2013-06-26  223.7100  229.9781  223.7100  228.7723  1028320
# 2013-06-27  228.1606  235.3862  228.1606  234.1095  1042380
# 2013-06-28  233.9500  233.9500  227.1676  227.7173  1407026

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('BLK')
financials.T
# Out:
#                                    0             1             2             3
# cashChange               -1068000000     698000000     598000000    -292000000
# cashFlow                  -141000000    1342000000    1347000000    1303000000
# costOfRevenue             1814000000    1520000000    1449000000    1348000000
# currentAssets             8758000000    9737000000    9430000000    8566000000
# currentCash               6143000000    6894000000    6165000000    5508000000
# currentDebt                     None          None          None          None
# grossProfit               1769000000    1949000000    1784000000    1617000000
# netIncome                 1089000000    2304000000     947000000     857000000
# operatingExpense           387000000     460000000     390000000     375000000
# operatingGainsLosses      -367000000    -258000000     -84000000     -90000000
# operatingIncome           1382000000    1489000000    1394000000    1242000000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('BLK')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-12  2018-01-12  2017-10-11  2017-07-17
# EPSSurpriseDollar             0.29        0.17        0.33       -0.15
# actualEPS                      6.7        6.24        5.92        5.24
# announceTime                   BTO         BTO         BTO         BTO
# consensusEPS                  6.41        6.07        5.59        5.39
# estimatedChangePercent    0.220952    0.180934   0.0875486    0.127615
# estimatedEPS                  6.41        6.07        5.59        5.39
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates                6           7           7           7
# symbolId                       796         796         796         796
# yearAgo                       5.25        5.14        5.14        4.78
# ...

# %%
iex.get_chart('BLK', chart_range='5y')
# Out:
#          change  changeOverTime  changePercent     close        date  \
# 0      5.550000        0.000000          2.321  244.6864  2013-06-17
# 1      0.443286        0.001812          0.181  245.1297  2013-06-18
# 2     -7.119200       -0.027283         -2.904  238.0105  2013-06-19
# 3    -14.584200       -0.086887         -6.128  223.4263  2013-06-20
# 4     -2.961200       -0.098989         -1.325  220.4651  2013-06-21
# 5     -2.695200       -0.110004         -1.223  217.7699  2013-06-24
# 6      6.161700       -0.084822          2.829  223.9316  2013-06-25
# 7      4.840700       -0.065039          2.162  228.7723  2013-06-26
# 8      5.337200       -0.043226          2.333  234.1095  2013-06-27
# 9     -6.392200       -0.069350         -2.730  227.7173  2013-06-28
# 10    -0.656063       -0.072031         -0.288  227.0613  2013-07-01
# 11     0.629468       -0.069459          0.277  227.6907  2013-07-02
# 12    -1.383100       -0.075111         -0.607  226.3077  2013-07-03
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('BLK'))
iex.get_quote('BLK')
# Out:
# {'symbol': 'BLK', 'delayedPrice': 524.52, 'high': 525.74, 'low': 516, 'delayedSize': 149839, 'delayedPriceTime': 1529093051904, 'processedTime': 1529093953306}
# {'symbol': 'BLK',
#  'companyName': 'BlackRock Inc.',
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Financial Services',
#  'calculationPrice': 'close',
#  'open': 520.82,
#  'openTime': 1529069498438,
#  'close': 524.52,
#  'closeTime': 1529093051904,
#  'high': 525.74,
#  'low': 516,
#  'latestPrice': 524.52,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529093051904,
#  'latestVolume': 714455,
#  'iexRealtimePrice': 524.48,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1529092797738,
#  'delayedPrice': 524.52,
#  'delayedPriceTime': 1529093051904,
#  'extendedPrice': 524.98,
#  'extendedChange': 0.46,
#  'extendedChangePercent': 0.00088,
#  'extendedPriceTime': 1529095922621,
#  'previousClose': 523.36,
#  'change': 1.16,
#  'changePercent': 0.00222,
# ...

# %%
iex.get_effective_spread('BLK')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.833091         0.465992          0.045343  XCHI            CHX
# 1          0.700788         0.321135          0.072027  XPHL     Nasdaq PSX
# 2          0.631860         0.315137          0.267578  XCIS  NYSE National
# 3          0.760920         0.292045          0.058498  ARCX      NYSE Arca
# 4          0.694192         0.290393          0.071275  BATY       Cboe BYX
# 5          0.688479         0.283007          0.077353  BATS       Cboe BZX
# 6          0.693500         0.270358          0.065479  EDGA      Cboe EDGA
# 7          0.741344         0.252552          0.058099  XNYS           NYSE
# 8          0.700188         0.252400          0.072956  EDGX      Cboe EDGX
# 9          0.704283         0.248752          0.068181  XBOS      Nasdaq BX
# 10         0.824061         0.248309          0.045849  XASE  NYSE American
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('BLK').T
# Out:
#                                          0
# EBITDA                          4421000000
# EPSSurpriseDollar                     None
# EPSSurprisePercent                  4.5242
# beta                               1.62312
# cash                           11829000000
# companyName                 BlackRock Inc.
# consensusEPS                          6.41
# day200MovingAvg                    505.548
# day30ChangePercent                0.013378
# day50MovingAvg                     528.435
# day5ChangePercent               -0.0446946
# debt                                     0
# dividendRate                         11.52
# dividendYield                      2.19629
# exDividendDate       2018-06-06 00:00:00.0
# float                            154982852
# grossProfit                     9292000000
# insiderPercent                        None
# institutionPercent                    75.7
# latestEPS                            30.21
# latestEPSDate                   2017-12-31
# ...
