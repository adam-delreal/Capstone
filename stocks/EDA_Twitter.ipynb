# %% [markdown]
# # Twitter (TWTR):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - Twitter:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/twitter_quandle.csv')
df.head()
# Out:
#          Date  WIKI/TWTR - Open  WIKI/TWTR - High  WIKI/TWTR - Low  \
# 0  2013-11-07             45.10             50.09            44.00
# 1  2013-11-08             45.93             46.94            40.69
# 2  2013-11-11             40.50             43.00            39.40
# 3  2013-11-12             43.66             43.78            41.83
# 4  2013-11-13             41.03             42.87            40.76
#
#    WIKI/TWTR - Close  WIKI/TWTR - Volume  WIKI/TWTR - Ex-Dividend  \
# 0              44.90         117701600.0                      0.0
# 1              41.65          27925300.0                      0.0
# 2              42.90          16113900.0                      0.0
# 3              41.90           6316700.0                      0.0
# 4              42.60           8688300.0                      0.0
#
#    WIKI/TWTR - Split Ratio  WIKI/TWTR - Adj. Open  WIKI/TWTR - Adj. High  \
# 0                      1.0                  45.10                  50.09
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Twitter's Stock:

# %%
twitter = Stock('TWTR')

# %%
print('Current Price:', twitter.get_price())
print('06/15/2018 Opening Price:', twitter.get_open())
print('06/15/2018 Closing Price:', twitter.get_close())
# Out:
# Current Price: 45.8
# 06/15/2018 Opening Price: 46.58
# 06/15/2018 Closing Price: 45.8

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

twitter_df = get_historical_data("TWTR", start=start, end=end, output_format='pandas')
twitter_df.head(10)
# Out:
#              open   high     low  close     volume
# date
# 2013-11-07  45.10  50.09  44.000  44.90  117647566
# 2013-11-08  45.93  46.94  40.685  41.65   27900126
# 2013-11-11  40.50  43.00  39.400  42.90   16109544
# 2013-11-12  43.66  43.78  41.830  41.90    6316205
# 2013-11-13  41.03  42.87  40.760  42.60    8675248
# 2013-11-14  42.34  45.67  42.240  44.69   11092320
# 2013-11-15  45.25  45.27  43.430  43.98    8010663
# 2013-11-18  43.50  43.95  40.850  41.14   12810624
# 2013-11-19  41.39  41.90  40.000  41.75    7436616
# 2013-11-20  41.40  41.75  40.510  41.05    5767325

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('TWTR')
financials.T
# Out:
#                                  0           1           2           3
# cashChange               -45355000    50682000   297958000    94071000
# cashFlow                 242673000   198107000   239947000   189707000
# costOfRevenue            222823000   217979000   210016000   212908000
# currentAssets           5409235000  5321884000  5002422000  4840102000
# currentCash             1630452000  1638413000  1586558000  1288323000
# currentDebt               86571000    84976000    81938000    80133000
# grossProfit              442048000   513581000   379617000   360947000
# netIncome                 60997000    91079000   -21095000  -116488000
# operatingExpense         367123000   403483000   372338000   399306000
# operatingGainsLosses          None        None        None        None
# operatingIncome           74925000   110098000     7279000   -38359000
# operatingRevenue         664871000   731560000   589633000   573855000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('TWTR')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-25  2018-02-08  2017-10-26  2017-07-27
# EPSSurpriseDollar             0.08        0.04        0.05         0.1
# actualEPS                     0.09         0.1        0.02       -0.02
# announceTime                   BTO         BTO         BTO         BTO
# consensusEPS                  0.01        0.06       -0.03       -0.12
# estimatedChangePercent         1.2           3         0.7  -0.0909091
# estimatedEPS                  0.01        0.06       -0.03       -0.12
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates                9           9           8           7
# symbolId                      8014        8014        8014        8014
# yearAgo                      -0.05       -0.03        -0.1       -0.11
# ...

# %%
iex.get_chart('TWTR', chart_range='5y')
# Out:
#       change  changeOverTime  changePercent  close        date     high  \
# 0      44.90        0.000000          0.000  44.90  2013-11-07  50.0900
# 1      -3.25       -0.072383         -7.238  41.65  2013-11-08  46.9400
# 2       1.25       -0.044543          3.001  42.90  2013-11-11  43.0000
# 3      -1.00       -0.066815         -2.331  41.90  2013-11-12  43.7800
# 4       0.70       -0.051225          1.671  42.60  2013-11-13  42.8700
# 5       2.09       -0.004677          4.906  44.69  2013-11-14  45.6700
# 6      -0.71       -0.020490         -1.589  43.98  2013-11-15  45.2700
# 7      -2.84       -0.083742         -6.457  41.14  2013-11-18  43.9500
# 8       0.61       -0.070156          1.483  41.75  2013-11-19  41.9000
# 9      -0.70       -0.085746         -1.677  41.05  2013-11-20  41.7500
# 10      1.01       -0.063252          2.460  42.06  2013-11-21  42.4900
# 11     -1.06       -0.086860         -2.520  41.00  2013-11-22  42.2800
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('TWTR'))
iex.get_quote('TWTR')
# Out:
# {'symbol': 'TWTR', 'delayedPrice': 45.8, 'high': 47.79, 'low': 45.64, 'delayedSize': 2741472, 'delayedPriceTime': 1529092947557, 'processedTime': 1529093849536}
# {'symbol': 'TWTR',
#  'companyName': 'Twitter Inc.',
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Technology',
#  'calculationPrice': 'close',
#  'open': 46.58,
#  'openTime': 1529069407673,
#  'close': 45.8,
#  'closeTime': 1529092947557,
#  'high': 47.79,
#  'low': 45.64,
#  'latestPrice': 45.8,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092947557,
#  'latestVolume': 51357527,
#  'iexRealtimePrice': 45.795,
#  'iexRealtimeSize': 200,
#  'iexLastUpdated': 1529092798513,
#  'delayedPrice': 45.8,
#  'delayedPriceTime': 1529092947557,
#  'extendedPrice': 45.92,
#  'extendedChange': 0.12,
#  'extendedChangePercent': 0.00262,
#  'extendedPriceTime': 1529096395647,
#  'previousClose': 46.76,
#  'change': -0.96,
#  'changePercent': -0.02053,
# ...

# %%
iex.get_effective_spread('TWTR')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.787440         0.023527          0.006763  XCHI            CHX
# 1          0.985672         0.009880          0.000126  XCIS  NYSE National
# 2          0.972152         0.009802          0.000199  EDGA      Cboe EDGA
# 3          0.953164         0.009741          0.000350  ARCX      NYSE Arca
# 4          0.956926         0.009674          0.000256  XBOS      Nasdaq BX
# 5          0.949497         0.009579          0.000442  EDGX      Cboe EDGX
# 6          0.943148         0.009520          0.000508  XPHL     Nasdaq PSX
# 7          0.935604         0.009465          0.000350  BATY       Cboe BYX
# 8          0.900004         0.009103          0.000705  XNGS         Nasdaq
# 9          0.891134         0.009058          0.000686  XNYS           NYSE
# 10         0.886351         0.008985          0.000801  BATS       Cboe BZX
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('TWTR').T
# Out:
#                                 0
# EBITDA                  335850000
# EPSSurpriseDollar            None
# EPSSurprisePercent            800
# beta                      1.02367
# cash                  12741110000
# companyName          Twitter Inc.
# consensusEPS                 0.01
# day200MovingAvg           26.2743
# day30ChangePercent       0.475515
# day50MovingAvg             33.684
# day5ChangePercent        0.105746
# debt                   5312247000
# dividendRate                    0
# dividendYield                   0
# exDividendDate                  0
# float                   738328740
# grossProfit            1254145000
# insiderPercent               None
# institutionPercent           56.9
# latestEPS                       0
# latestEPSDate          2017-12-31
# marketcap             34472126524
# month1ChangePercent      0.398473
# month3ChangePercent       0.27933
# month6ChangePercent       1.06028
# numberOfEstimates               9
# ...
