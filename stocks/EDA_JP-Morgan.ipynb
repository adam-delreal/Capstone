# %% [markdown]
# # JP Morgan (JPM):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - JP Morgan:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/jpm_quandle.csv')
df.head()
# Out:
#          Date  WIKI/JPM - Open  WIKI/JPM - High  WIKI/JPM - Low  \
# 0  1983-12-30            44.00            44.50           43.50
# 1  1984-01-03            43.94            44.25           43.62
# 2  1984-01-04            44.84            45.87           44.25
# 3  1984-01-05            46.81            47.38           46.25
# 4  1984-01-06            46.88            47.38           46.38
#
#    WIKI/JPM - Close  WIKI/JPM - Volume  WIKI/JPM - Ex-Dividend  \
# 0             44.00            47000.0                     0.0
# 1             44.00            85667.0                     0.0
# 2             45.87            65000.0                     0.0
# 3             47.38            76467.0                     0.0
# 4             46.88            43200.0                     0.0
#
#    WIKI/JPM - Split Ratio  WIKI/JPM - Adj. Open  WIKI/JPM - Adj. High  \
# 0                     1.0              3.074327              3.109262
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Apple's Stock:

# %%
jp_morgan = Stock('JPM')

# %%
print('Current Price:', jp_morgan.get_price())
print('06/15/2018 Opening Price:', jp_morgan.get_open())
print('06/15/2018 Closing Price:', jp_morgan.get_close())
# Out:
# Current Price: 107.9
# 06/15/2018 Opening Price: 107.9
# 06/15/2018 Closing Price: 107.9

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

jpm_df = get_historical_data("JPM", start=start, end=end, output_format='pandas')
jpm_df.head(10)
# Out:
#                open     high      low    close    volume
# date
# 2013-06-17  47.1648  47.6522  47.0242  47.2965  16855353
# 2013-06-18  47.4546  47.6654  47.1823  47.5249  13253408
# 2013-06-19  47.4195  47.8762  47.0067  47.0330  20838070
# 2013-06-20  46.6202  46.7080  45.9088  46.0932  31862273
# 2013-06-21  46.5148  46.5324  45.3994  45.6365  44414895
# 2013-06-24  44.6880  45.1886  44.0117  44.7231  30555014
# 2013-06-25  45.2413  46.1674  45.2413  45.7419  20899419
# 2013-06-26  46.2425  46.3743  45.5645  46.1108  19331616
# 2013-06-27  46.5763  46.9803  46.4446  46.6817  17094217
# 2013-06-28  46.6553  46.6641  46.1811  46.3655  18262487

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('JPM')
financials.T
# Out:
#                                     0              1              2  \
# cashChange               -19541000000     3833000000      217000000
# cashFlow                 -35109000000    13537000000    -3014000000
# costOfRevenue                    None           None           None
# currentAssets                    None           None           None
# currentCash              414812000000    25827000000    21994000000
# currentDebt               27486000000    50647000000    24248000000
# grossProfit                      None           None           None
# netIncome                  8712000000     4232000000     6732000000
# operatingExpense                 None           None           None
# operatingGainsLosses             None           None           None
# operatingIncome                  None           None           None
# operatingRevenue                 None           None           None
# reportDate                 2018-03-31     2017-12-31     2017-09-30
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('JPM')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-13  2018-01-12  2017-10-12  2017-07-14
# EPSSurpriseDollar             0.09        0.07        0.09        0.25
# actualEPS                     2.37        1.76        1.76        1.82
# announceTime                   BTO         BTO         BTO         BTO
# consensusEPS                  2.28        1.69        1.67        1.57
# estimatedChangePercent    0.381818  -0.0116959    0.056962   0.0129032
# estimatedEPS                  2.28        1.69        1.67        1.57
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates                8           8           8           7
# symbolId                      3821        3821        3821        3821
# yearAgo                       1.65        1.71        1.58        1.55
# ...

# %%
iex.get_chart('JPM', chart_range='5y')
# Out:
#         change  changeOverTime  changePercent     close        date      high  \
# 0     0.632377        0.000000          1.355   47.2965  2013-06-17   47.6522
# 1     0.228356        0.004829          0.483   47.5249  2013-06-18   47.6654
# 2    -0.491847       -0.005571         -1.035   47.0330  2013-06-19   47.8762
# 3    -0.939781       -0.025442         -1.998   46.0932  2013-06-20   46.7080
# 4    -0.456716       -0.035098         -0.991   45.6365  2013-06-21   46.5324
# 5    -0.913433       -0.054410         -2.002   44.7231  2013-06-24   45.1886
# 6     1.018800       -0.032869          2.278   45.7419  2013-06-25   46.1674
# 7     0.368886       -0.025070          0.806   46.1108  2013-06-26   46.3743
# 8     0.570896       -0.012999          1.238   46.6817  2013-06-27   46.9803
# 9    -0.316190       -0.019684         -0.677   46.3655  2013-06-28   46.6641
# 10    0.072677       -0.018147          0.157   46.4382  2013-07-01   47.4467
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('JPM'))
iex.get_quote('JPM')
# Out:
# {'symbol': 'JPM', 'delayedPrice': 107.9, 'high': 108.38, 'low': 106.27, 'delayedSize': 6743663, 'delayedPriceTime': 1529092813015, 'processedTime': 1529093713509}
# {'symbol': 'JPM',
#  'companyName': 'JP Morgan Chase & Co.',
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Financial Services',
#  'calculationPrice': 'close',
#  'open': 107.9,
#  'openTime': 1529069408152,
#  'close': 107.9,
#  'closeTime': 1529092813015,
#  'high': 108.38,
#  'low': 106.27,
#  'latestPrice': 107.9,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092813015,
#  'latestVolume': 25805943,
#  'iexRealtimePrice': 107.865,
#  'iexRealtimeSize': 62,
#  'iexLastUpdated': 1529092796650,
#  'delayedPrice': 107.9,
#  'delayedPriceTime': 1529092813015,
#  'extendedPrice': 107.92,
#  'extendedChange': 0.02,
#  'extendedChangePercent': 0.00019,
#  'extendedPriceTime': 1529096297637,
#  'previousClose': 108.03,
#  'change': -0.13,
#  'changePercent': -0.0012,
# ...

# %%
iex.get_effective_spread('JPM')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.842024         0.010334          0.001699  XCHI            CHX
# 1          0.919692         0.010253          0.000543  BATY       Cboe BYX
# 2          0.940314         0.010165          0.000489  XBOS      Nasdaq BX
# 3          0.934248         0.010035          0.000581  EDGA      Cboe EDGA
# 4          0.892743         0.009715          0.001049  ARCX      NYSE Arca
# 5          0.929354         0.009647          0.000706  XCIS  NYSE National
# 6          0.885636         0.009548          0.001116  EDGX      Cboe EDGX
# 7          0.874870         0.009399          0.001322  XPHL     Nasdaq PSX
# 8          0.858130         0.009393          0.001280  XNYS           NYSE
# 9          0.837943         0.009132          0.001484  BATS       Cboe BZX
# 10         0.812411         0.008686          0.001739  XNGS         Nasdaq
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('JPM').T
# Out:
#                                          0
# EBITDA                                   0
# EPSSurpriseDollar                     None
# EPSSurprisePercent                  3.9474
# beta                               1.18796
# cash                                     0
# companyName          JP Morgan Chase & Co.
# consensusEPS                          2.28
# day200MovingAvg                    105.668
# day30ChangePercent             -0.00488795
# day50MovingAvg                     110.444
# day5ChangePercent               -0.0264369
# debt                         1024547000000
# dividendRate                          2.24
# dividendYield                        2.076
# exDividendDate       2018-07-05 00:00:00.0
# float                           3387110403
# grossProfit                              0
# insiderPercent                        None
# institutionPercent                    64.8
# latestEPS                             6.32
# latestEPSDate                   2017-12-31
# ...
