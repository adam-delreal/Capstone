# %% [markdown]
# # IBM (IBM):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - IBM:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/ibm_quandle.csv')
df.head()
# Out:
#          Date  WIKI/IBM - Open  WIKI/IBM - High  WIKI/IBM - Low  \
# 0  1962-01-02            578.5            578.5           572.0
# 1  1962-01-03            572.0            577.0           572.0
# 2  1962-01-04            577.0            577.0           571.0
# 3  1962-01-05            570.5            570.5           559.0
# 4  1962-01-08            559.5            559.5           545.0
#
#    WIKI/IBM - Close  WIKI/IBM - Volume  WIKI/IBM - Ex-Dividend  \
# 0            572.00            19360.0                     0.0
# 1            577.00            14400.0                     0.0
# 2            571.25            12800.0                     0.0
# 3            560.00            18160.0                     0.0
# 4            549.50            27200.0                     0.0
#
#    WIKI/IBM - Split Ratio  WIKI/IBM - Adj. Open  WIKI/IBM - Adj. High  \
# 0                     1.0             15.270839             15.270839
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for IBM's Stock:

# %%
ibm = Stock('IBM')

# %%
print('Current Price:', ibm.get_price())
print('06/15/2018 Opening Price:', ibm.get_open())
print('06/15/2018 Closing Price:', ibm.get_close())
# Out:
# Current Price: 145.39
# 06/15/2018 Opening Price: 144.73
# 06/15/2018 Closing Price: 145.39

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

ibm_df = get_historical_data("IBM", start=start, end=end, output_format='pandas')
ibm_df.head(10)
# Out:
#                 open      high       low     close    volume
# date
# 2013-06-17  172.8835  174.3548  172.1272  172.5436   3220009
# 2013-06-18  172.5266  175.1355  172.3991  174.0987   3278051
# 2013-06-19  173.7333  174.2347  171.6003  171.6088   2846004
# 2013-06-20  170.5296  171.4048  167.6487  167.7082   4516229
# 2013-06-21  168.6855  168.7025  164.4706  166.1021   8918718
# 2013-06-24  164.8529  165.6347  162.6009  164.4705   4356153
# 2013-06-25  165.9746  166.2126  164.1390  165.6942   3847821
# 2013-06-26  166.5355  166.7564  165.2863  165.5922   3319852
# 2013-06-27  166.6035  167.3258  165.9576  166.2636   3515357
# 2013-06-28  162.9323  163.7226  160.1110  162.4055  10056556

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('IBM')
financials.T
# Out:
#                                    0             1             2             3
# cashChange                 -72000000     995000000   -1109000000    1200000000
# cashFlow                  4602000000    5733000000    3570000000    3466000000
# costOfRevenue            10825000000   11681000000   10353000000   10495000000
# currentAssets            49122000000   49735000000   44742000000   45013000000
# currentCash              12262000000   11972000000   10915000000   11696000000
# currentDebt               5977000000    6986000000    4299000000    8061000000
# grossProfit               8247000000   10862000000    8800000000    8794000000
# netIncome                 1679000000   -1054000000    2726000000    2331000000
# operatingExpense          6533000000    6225000000    5681000000    6279000000
# operatingGainsLosses        34000000     -78000000      18000000      61000000
# operatingIncome           1714000000    4637000000    3119000000    2515000000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('MSFT')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-26  2018-01-31  2017-10-26  2017-07-20
# EPSSurpriseDollar              0.1         0.1        0.12        0.27
# actualEPS                     0.95        0.96        0.84        0.98
# announceTime                   AMC         AMC         AMC         AMC
# consensusEPS                  0.85        0.86        0.72        0.71
# estimatedChangePercent    0.164384   0.0361446  -0.0526316   0.0289855
# estimatedEPS                  0.85        0.86        0.72        0.71
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q3 2018     Q2 2018     Q1 2018     Q4 2017
# numberOfEstimates               14          14          14          14
# symbolId                      4563        4563        4563        4563
# yearAgo                       0.73        0.83        0.76        0.69
# ...

# %%
iex.get_chart('IBM', chart_range='5y')
# Out:
#         change  changeOverTime  changePercent     close        date      high  \
# 0     0.713833        0.000000          0.415  172.5436  2013-06-17  174.3548
# 1     1.555100        0.009013          0.901  174.0987  2013-06-18  175.1355
# 2    -2.489900       -0.005418         -1.430  171.6088  2013-06-19  174.2347
# 3    -3.900600       -0.028024         -2.273  167.7082  2013-06-20  171.4048
# 4    -1.606100       -0.037333         -0.958  166.1021  2013-06-21  168.7025
# 5    -1.631600       -0.046789         -0.982  164.4705  2013-06-24  165.6347
# 6     1.223700       -0.039697          0.744  165.6942  2013-06-25  166.2126
# 7    -0.101976       -0.040288         -0.062  165.5922  2013-06-26  166.7564
# 8     0.671342       -0.036397          0.405  166.2636  2013-06-27  167.3258
# 9    -3.858100       -0.058757         -2.320  162.4055  2013-06-28  163.7226
# 10    0.144469       -0.057920          0.089  162.5499  2013-07-01  164.6914
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('IBM'))
iex.get_quote('IBM')
# Out:
# {'symbol': 'IBM', 'delayedPrice': 145.39, 'high': 145.47, 'low': 143.7, 'delayedSize': 2610829, 'delayedPriceTime': 1529092950538, 'processedTime': 1529093851536}
# {'symbol': 'IBM',
#  'companyName': 'International Business Machines Corporation',
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Technology',
#  'calculationPrice': 'close',
#  'open': 144.73,
#  'openTime': 1529069458447,
#  'close': 145.39,
#  'closeTime': 1529092950538,
#  'high': 145.47,
#  'low': 143.7,
#  'latestPrice': 145.39,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092950538,
#  'latestVolume': 8548747,
#  'iexRealtimePrice': 145.36,
#  'iexRealtimeSize': 300,
#  'iexLastUpdated': 1529092795035,
#  'delayedPrice': 145.39,
#  'delayedPriceTime': 1529092950538,
#  'extendedPrice': 145.69,
#  'extendedChange': 0.3,
#  'extendedChangePercent': 0.00206,
#  'extendedPriceTime': 1529096361637,
#  'previousClose': 145.2,
#  'change': 0.19,
# ...

# %%
iex.get_effective_spread('IBM')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.758598         0.034448          0.005274  XCHI            CHX
# 1          0.839087         0.027314          0.003066  XCIS  NYSE National
# 2          0.876160         0.016855          0.001850  BATY       Cboe BYX
# 3          0.825251         0.016263          0.002442  XBOS      Nasdaq BX
# 4          0.861489         0.014852          0.001904  ARCX      NYSE Arca
# 5          0.755325         0.014210          0.003318  BATS       Cboe BZX
# 6          0.778097         0.014029          0.002901  XNYS           NYSE
# 7          0.768972         0.013861          0.003178  XASE  NYSE American
# 8          0.842652         0.013510          0.002233  EDGA      Cboe EDGA
# 9          0.761312         0.013463          0.003436  EDGX      Cboe EDGX
# 10         0.700582         0.011709          0.004053  XPHL     Nasdaq PSX
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('IBM').T
# Out:
#                                                                0
# EBITDA                                               13899000000
# EPSSurpriseDollar                                           None
# EPSSurprisePercent                                        2.0833
# beta                                                    0.889261
# cash                                                 23810000000
# companyName          International Business Machines Corporation
# consensusEPS                                                 2.4
# day200MovingAvg                                          149.054
# day30ChangePercent                                     0.0214993
# day50MovingAvg                                           145.642
# day5ChangePercent                                    -0.00811843
# debt                                                 91299000000
# dividendRate                                                6.28
# ...
