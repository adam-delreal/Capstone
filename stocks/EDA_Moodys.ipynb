# %% [markdown]
# # Moody's (MCO)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - Moody's:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/moodys_quandle.csv')
df.head()
# Out:
#          Date  WIKI/MCO - Open  WIKI/MCO - High  WIKI/MCO - Low  \
# 0  1994-10-31            16.38            16.62           16.38
# 1  1994-11-01            16.62            16.62           16.38
# 2  1994-11-02            16.50            16.50           16.38
# 3  1994-11-03            16.38            16.50           16.25
# 4  1994-11-04            16.38            16.50           16.25
#
#    WIKI/MCO - Close  WIKI/MCO - Volume  WIKI/MCO - Ex-Dividend  \
# 0             16.62           992100.0                     0.0
# 1             16.50          1088200.0                     0.0
# 2             16.38          1174100.0                     0.0
# 3             16.38          1030400.0                     0.0
# 4             16.25          1331900.0                     0.0
#
#    WIKI/MCO - Split Ratio  WIKI/MCO - Adj. Open  WIKI/MCO - Adj. High  \
# 0                     1.0              1.033628              1.048773
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Moody's Stock:

# %%
moodys = Stock('MCO')

# %%
print('Current Price:', moodys.get_price())
print('06/15/2018 Opening Price:', moodys.get_open())
print('06/15/2018 Closing Price:', moodys.get_close())
# Out:
# Current Price: 176.8
# 06/15/2018 Opening Price: 175.58
# 06/15/2018 Closing Price: 176.8

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

black_df = get_historical_data("MCO", start=start, end=end, output_format='pandas')
black_df.head(10)
# Out:
#                open     high      low    close   volume
# date
# 2013-06-17  58.7874  58.8904  58.0201  58.1979  1473297
# 2013-06-18  58.3195  58.7874  58.0294  58.5909   978613
# 2013-06-19  58.5067  58.7650  57.0562  57.0936  1349372
# 2013-06-20  56.4854  56.9345  54.8945  55.0255  1990528
# 2013-06-21  55.4560  55.6712  54.2394  55.1004  1747954
# 2013-06-24  54.3517  54.4734  53.1071  53.9400  1409493
# 2013-06-25  54.7728  55.6806  54.3798  54.6793  1233255
# 2013-06-26  55.1565  55.4934  54.8009  55.0442  1090799
# 2013-06-27  55.4934  57.0936  55.0442  56.9252  1672131
# 2013-06-28  56.7942  57.5241  56.6819  57.0188  2563706

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('MCO')
financials.T
# Out:
#                                  0           1            2           3
# cashChange               190700000   102700000  -2337800000  1109900000
# cashFlow                 391500000   404800000    390400000   464700000
# costOfRevenue            314900000   342400000    317200000   285800000
# currentAssets           2818800000  2580600000   2278900000  4559100000
# currentCash             1277300000  1071500000    962800000  3280900000
# currentDebt              3.896e+08   4.294e+08    6.141e+08         NaN
# grossProfit              811800000   823100000    745700000   714700000
# netIncome                372900000    25500000    317300000   312200000
# operatingExpense         322600000   354500000    290200000   250600000
# operatingGainsLosses     -1.45e+07    -9.9e+07          NaN     3.2e+06
# operatingIncome          489200000   468600000    455500000   464100000
# operatingRevenue        1126700000  1165500000   1062900000  1000500000
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('MCO')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-27  2018-02-09  2017-11-03  2017-07-21
# EPSSurpriseDollar             0.24        0.06        0.12        0.18
# actualEPS                     2.02        1.51        1.52        1.51
# announceTime                   BTO         BTO         BTO         BTO
# consensusEPS                  1.78        1.45         1.4        1.33
# estimatedChangePercent    0.210884    0.178862   0.0447761   0.0230769
# estimatedEPS                  1.78        1.45         1.4        1.33
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates                6           6           4           5
# symbolId                      4273        4273        4273        4273
# yearAgo                       1.47        1.23        1.34         1.3
# ...

# %%
iex.get_chart('MCO', chart_range='5y')
# Out:
#         change  changeOverTime  changePercent     close        date      high  \
# 0    -0.009356        0.000000         -0.016   58.1979  2013-06-17   58.8904
# 1     0.393037        0.006753          0.675   58.5909  2013-06-18   58.7874
# 2    -1.497300       -0.018975         -2.555   57.0936  2013-06-19   58.7650
# 3    -2.068100       -0.054511         -3.622   55.0255  2013-06-20   56.9345
# 4     0.074863       -0.053224          0.136   55.1004  2013-06-21   55.6712
# 5    -1.160400       -0.073162         -2.106   53.9400  2013-06-24   54.4734
# 6     0.739288       -0.060459          1.371   54.6793  2013-06-25   55.6806
# 7     0.364967       -0.054189          0.667   55.0442  2013-06-26   55.4934
# 8     1.881000       -0.021868          3.417   56.9252  2013-06-27   57.0936
# 9     0.093586       -0.020260          0.164   57.0188  2013-06-28   57.5241
# 10    0.346246       -0.014312          0.607   57.3650  2013-07-01   58.6284
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('MCO'))
iex.get_quote('MCO')
# Out:
# {'symbol': 'MCO', 'delayedPrice': 176.8, 'high': 176.99, 'low': 174.68, 'delayedSize': 279119, 'delayedPriceTime': 1529093051580, 'processedTime': 1529093953306}
# {'symbol': 'MCO',
#  'companyName': "Moody's Corporation",
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Financial Services',
#  'calculationPrice': 'close',
#  'open': 175.58,
#  'openTime': 1529069641134,
#  'close': 176.8,
#  'closeTime': 1529093051580,
#  'high': 176.99,
#  'low': 174.68,
#  'latestPrice': 176.8,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529093051580,
#  'latestVolume': 914540,
#  'iexRealtimePrice': 176.77,
#  'iexRealtimeSize': 2,
#  'iexLastUpdated': 1529092796027,
#  'delayedPrice': 176.8,
#  'delayedPriceTime': 1529093051580,
#  'extendedPrice': 177,
#  'extendedChange': 0.2,
#  'extendedChangePercent': 0.00113,
#  'extendedPriceTime': 1529096107838,
#  'previousClose': 175.93,
#  'change': 0.87,
#  'changePercent': 0.00495,
# ...

# %%
iex.get_effective_spread('MCO')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.682121         0.084425          0.017067  XCHI            CHX
# 1          0.633441         0.079264          0.024281  XPHL     Nasdaq PSX
# 2          0.871047         0.062202          0.005699  ARCX      NYSE Arca
# 3          0.682159         0.056932          0.015161  BATS       Cboe BZX
# 4          0.754863         0.055810          0.010284  BATY       Cboe BYX
# 5          0.710356         0.049995          0.012479  EDGX      Cboe EDGX
# 6          0.724398         0.049057          0.010733  XNYS           NYSE
# 7          0.739624         0.047737          0.010275  XBOS      Nasdaq BX
# 8          0.721561         0.045111          0.011324  EDGA      Cboe EDGA
# 9          0.617062         0.044781          0.014723  XNGS         Nasdaq
# 10         0.727891         0.041082          0.011568  XASE  NYSE American
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('MCO').T
# Out:
#                                          0
# EBITDA                          1618400000
# EPSSurpriseDollar                     None
# EPSSurprisePercent                 13.4831
# beta                               1.19425
# cash                            5621600000
# companyName            Moody's Corporation
# consensusEPS                          1.78
# day200MovingAvg                    155.327
# day30ChangePercent               0.0658089
# day50MovingAvg                     169.202
# day5ChangePercent              -0.00573614
# debt                           10608500000
# dividendRate                          1.76
# dividendYield                     0.995475
# exDividendDate       2018-05-18 00:00:00.0
# float                            190677239
# grossProfit                     2283500000
# insiderPercent                        None
# institutionPercent                    79.1
# latestEPS                             5.15
# latestEPSDate                   2017-12-31
# ...
