# %% [markdown]
# # Goldman Sachs (GS):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import quandl

import iex as IEX

from iexfinance import Stock
from iexfinance import get_historical_data
from iexfinance import get_stats_intraday

from datetime import datetime

quandl.ApiConfig.api_key = "9tQnPMV9zakeCm4K6S5X"

# %%
! ls data
# Out:
# EOD-datasets-codes.csv facebook_quandle.csv   jpm_quandle.csv
# apple_quandle.csv      google_quandle.csv     microsoft_quandle.csv
# blackrock_quandle.csv  gs_quandle.csv         moodys_quandle.csv
# dow_quandle.csv        ibm_quandle.csv        twitter_quandle.csv

# %% [markdown]
# ## Importing Stock History - Goldman Sachs:
#
# - **From Quadle**

# %%
df = pd.read_csv('data/gs_quandle.csv')
df.head()
# Out:
#          Date  WIKI/GS - Open  WIKI/GS - High  WIKI/GS - Low  WIKI/GS - Close  \
# 0  1999-05-04           76.00           77.25          70.00            70.38
# 1  1999-05-05           69.88           69.88          66.25            69.13
# 2  1999-05-06           68.00           69.38          67.06            67.94
# 3  1999-05-07           67.94           74.88          66.75            74.13
# 4  1999-05-10           73.38           73.50          70.25            70.69
#
#    WIKI/GS - Volume  WIKI/GS - Ex-Dividend  WIKI/GS - Split Ratio  \
# 0        22320900.0                    0.0                    1.0
# 1         7565700.0                    0.0                    1.0
# 2         2905700.0                    0.0                    1.0
# 3         4862300.0                    0.0                    1.0
# 4         2589400.0                    0.0                    1.0
#
#    WIKI/GS - Adj. Open  WIKI/GS - Adj. High  WIKI/GS - Adj. Low  \
# ...

# %% [markdown]
# -------
#
# ## Querying IEX for Goldman Sachs's Stock:

# %%
goldman = Stock('GS')

# %%
print('Current Price:', goldman.get_price())
print('06/15/2018 Opening Price:', goldman.get_open())
print('06/15/2018 Closing Price:', goldman.get_close())
# Out:
# Current Price: 231.92
# 06/15/2018 Opening Price: 230.97
# 06/15/2018 Closing Price: 231.92

# %% [markdown]
# ## Historical Data from IEX:

# %%
start = datetime(2013, 1, 1) ## 5 year limit:
end = datetime(2018, 6, 15) ## Today's Date

goldman_df = get_historical_data("GS", start=start, end=end, output_format='pandas')
goldman_df.head(10)
# Out:
#                 open      high       low     close   volume
# date
# 2013-06-17  153.4483  154.9352  152.3494  153.4763  2628240
# 2013-06-18  153.5137  154.1870  152.4850  153.5137  2059734
# 2013-06-19  153.5231  154.2432  151.0448  151.0916  3554203
# 2013-06-20  148.8377  149.6233  144.8070  145.3401  6488769
# 2013-06-21  146.8270  147.0702  142.4316  144.2552  5390489
# 2013-06-24  142.1416  142.7121  139.0742  141.0101  4012960
# 2013-06-25  142.5719  144.3113  141.7302  143.1423  3274809
# 2013-06-26  144.4703  144.5451  140.9820  141.8330  3580307
# 2013-06-27  143.1143  144.9473  142.7215  143.5632  2654849
# 2013-06-28  142.7963  142.8711  141.2158  141.4496  3013155

# %% [markdown]
# ## Financial Statement:

# %%
iex = IEX.Stock()
financials = iex.get_financials('GS')
financials.T
# Out:
#                                    0             1             2             3
# cashChange               10452000000   -6559000000    5722000000  -12147000000
# cashFlow                  -964000000   -6623000000    2734000000  -10464000000
# costOfRevenue                   None          None          None          None
# currentAssets                   None          None          None          None
# currentCash             120503000000  110051000000  116610000000  110888000000
# currentDebt              47760000000   46922000000   45357000000   42966000000
# grossProfit                     None          None          None          None
# netIncome                 2832000000   -1928000000    2128000000    1831000000
# operatingExpense                None          None          None          None
# operatingGainsLosses             NaN        -6e+06           NaN           NaN
# operatingIncome                 None          None          None          None
# ...

# %% [markdown]
# ## Earnings:
#
# https://www.wallstreetmojo.com/revenue-vs-earnings/

# %%
earnings = iex.get_earnings('GS')
earnings.T
# Out:
#                                  0           1           2           3
# EPSReportDate           2018-04-17  2018-01-17  2017-10-17  2017-07-18
# EPSSurpriseDollar             1.28        0.78        0.71        0.59
# actualEPS                     6.95        5.68        5.02        3.95
# announceTime                   BTO         BTO         BTO         BTO
# consensusEPS                  5.67         4.9        4.31        3.36
# estimatedChangePercent    0.100971  -0.0354331   -0.116803  -0.0967742
# estimatedEPS                  5.67         4.9        4.31        3.36
# fiscalEndDate           2018-03-31  2017-12-31  2017-09-30  2017-06-30
# fiscalPeriod               Q1 2018     Q4 2017     Q3 2017     Q2 2017
# numberOfEstimates                6           6           7           5
# symbolId                      3004        3004        3004        3004
# yearAgo                       5.15        5.08        4.88        3.72
# ...

# %%
iex.get_chart('GS', chart_range='5y')
# Out:
#         change  changeOverTime  changePercent     close        date      high  \
# 0     1.112900        0.000000          0.730  153.4763  2013-06-17  154.9352
# 1     0.037407        0.000244          0.024  153.5137  2013-06-18  154.1870
# 2    -2.422200       -0.015538         -1.578  151.0916  2013-06-19  154.2432
# 3    -5.751500       -0.053013         -3.807  145.3401  2013-06-20  149.6233
# 4    -1.084800       -0.060082         -0.746  144.2552  2013-06-21  147.0702
# 5    -3.245200       -0.081226         -2.250  141.0101  2013-06-24  142.7121
# 6     2.132300       -0.067333          1.512  143.1423  2013-06-25  144.3113
# 7    -1.309300       -0.075864         -0.915  141.8330  2013-06-26  144.5451
# 8     1.730100       -0.064590          1.220  143.5632  2013-06-27  144.9473
# 9    -2.113600       -0.078362         -1.472  141.4496  2013-06-28  142.8711
# 10    0.467606       -0.075315          0.331  141.9172  2013-07-01  144.1149
# ...

# %% [markdown]
# ## Getting a Quote:

# %%
print(iex.get_delayed_quote('GS'))
iex.get_quote('GS')
# Out:
# {'symbol': 'GS', 'delayedPrice': 231.92, 'high': 233.15, 'low': 229.84, 'delayedSize': 620361, 'delayedPriceTime': 1529092918341, 'processedTime': 1529093819530}
# {'symbol': 'GS',
#  'companyName': 'Goldman Sachs Group Inc. (The)',
#  'primaryExchange': 'New York Stock Exchange',
#  'sector': 'Financial Services',
#  'calculationPrice': 'close',
#  'open': 230.97,
#  'openTime': 1529069474508,
#  'close': 231.92,
#  'closeTime': 1529092918341,
#  'high': 233.15,
#  'low': 229.84,
#  'latestPrice': 231.92,
#  'latestSource': 'Close',
#  'latestTime': 'June 15, 2018',
#  'latestUpdate': 1529092918341,
#  'latestVolume': 4666857,
#  'iexRealtimePrice': 231.94,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1529092795338,
#  'delayedPrice': 231.92,
#  'delayedPriceTime': 1529092918341,
#  'extendedPrice': 231.5,
#  'extendedChange': -0.42,
#  'extendedChangePercent': -0.00181,
#  'extendedPriceTime': 1529096030874,
#  'previousClose': 233.65,
#  'change': -1.73,
# ...

# %%
iex.get_effective_spread('GS')
# Out:
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.631347         0.053163          0.014289  XCHI            CHX
# 1          0.753536         0.042525          0.008091  BATY       Cboe BYX
# 2          0.750576         0.041396          0.007868  XBOS      Nasdaq BX
# 3          0.665382         0.039221          0.011274  BATS       Cboe BZX
# 4          0.644689         0.039186          0.012266  XPHL     Nasdaq PSX
# 5          0.721086         0.037745          0.008596  XNYS           NYSE
# 6          0.701846         0.037678          0.009506  ARCX      NYSE Arca
# 7          0.651590         0.036900          0.006773  XCIS  NYSE National
# 8          0.748588         0.036880          0.008057  EDGA      Cboe EDGA
# 9          0.675634         0.033505          0.010110  EDGX      Cboe EDGX
# 10         0.610602         0.031154          0.011553  XNGS         Nasdaq
# ...

# %% [markdown]
# ## Stats:

# %%
iex.get_stats('GS').T
# Out:
#                                                   0
# EBITDA                                            0
# EPSSurpriseDollar                              None
# EPSSurprisePercent                           22.575
# beta                                        1.30865
# cash                                              0
# companyName          Goldman Sachs Group Inc. (The)
# consensusEPS                                   5.67
# day200MovingAvg                             245.104
# day30ChangePercent                      -0.00936346
# day50MovingAvg                              239.521
# day5ChangePercent                       -0.00926994
# debt                                   548994000000
# dividendRate                                    3.2
# dividendYield                               1.37979
# exDividendDate                2018-05-30 00:00:00.0
# float                                     359648733
# grossProfit                                       0
# ...
