# %% [markdown]
# # Apple, Inc. (AAPL)
#
# ## Importing Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from datetime import datetime

from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit

from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier


import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# -----
#
# ## Company Name

# %%
company_name = 'Apple'

# %% [markdown]
# ## Importing the Data:

# %%
def data_reader(company_name):
    company_name=company_name
    df = pd.read_csv(f'data/{company_name}_Clean.csv')
    df['Date'] = pd.to_datetime(df.Date)
    df.set_index('Date', inplace=True)
    df.sort_index(inplace=True, ascending=True)
    return df

# %%
# def engineered_data_reader(company_name):
#     company_name=company_name
#     df = pd.read_csv(f'data/{company_name}_Engineered.csv')
#     df['Date'] = pd.to_datetime(df.Date)
#     df.set_index('Date', inplace=True)
#     df.sort_index(inplace=True, ascending=True)
#     return df

# %%
df = data_reader(company_name)
df.head(3)
# Out:
#              Open   High    Low  Close     Volume  Ex_Dividend  Split_Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
#
#             Adj_Open  Adj_High   Adj_Low  Adj_Close   Adj_Volume
# Date
# 1980-12-12  0.422706  0.424470  0.422706   0.422706  117258400.0
# 1980-12-15  0.402563  0.402563  0.400652   0.400652   43971200.0
# 1980-12-16  0.373010  0.373010  0.371246   0.371246   26432000.0

# %%
# df_engineered = engineered_data_reader(company_name)

# %%
# df_engineered.head(3)
# Out:
#              Open   High    Low  Close     Volume  Ex_Dividend  Split_Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
#
#             Adj_Open  Adj_High   Adj_Low         ...           Low_Long_EMA  \
# Date                                             ...
# 1980-12-12  0.422706  0.424470  0.422706         ...              28.750000
# 1980-12-15  0.402563  0.402563  0.400652         ...              28.715116
# 1980-12-16  0.373010  0.373010  0.371246         ...              28.634532
#
#             Close_Long_EMA  Volume_Long_EMA  Ex_Dividend_Long_EMA  \
# Date
# 1980-12-12       28.750000     2.093900e+06                   0.0
# 1980-12-15       28.715116     2.063465e+06                   0.0
# 1980-12-16       28.634532     2.026454e+06                   0.0
#
#             Split_Ratio_Long_EMA  Adj_Open_Long_EMA  Adj_High_Long_EMA  \
# Date
# 1980-12-12                   1.0           0.422706           0.424470
# 1980-12-15                   1.0           0.422237           0.423961
# 1980-12-16                   1.0           0.421093           0.422776
#
#             Adj_Low_Long_EMA  Adj_Close_Long_EMA  Adj_Volume_Long_EMA
# Date
# 1980-12-12          0.422706            0.422706         1.172584e+08
# 1980-12-15          0.422193            0.422193         1.155540e+08
# 1980-12-16          0.421008            0.421008         1.134814e+08
#
# [3 rows x 84 columns]

# %%
# def reader(company_name):
#     company_name = company_name
    
#     stock = pd.read_csv(f'data/{company_name}_Engineered.csv')
#     stock['Date'] = pd.to_datetime(stock.Date)
#     stock.set_index('Date', inplace=True)
    
#     sec_filings = pd.read_csv(f'../sec/data/{company_name}_SEC_clean.csv')

#     sec_filings.rename({'date':'Date'}, axis=1, inplace=True)
#     sec_filings['Date'] = pd.to_datetime(sec_filings.Date)
#     sec_filings.set_index('Date', inplace=True)

#     data = pd.merge(stock, sec_filings, on='Date', how='inner')
#     data.reset_index(level=0, inplace=True)
#     return data

# %%
# df = reader(company_name)

# %%
# df.head()

# %% [markdown]
# -----
#
# # Splitting the Data a Training and Testing Set
#
# ## Creating a Function for the Training Set with Feature Engineering:

# %%
def shift_dates(df):
    shifted_df = pd.DataFrame(df[:-1].values, index = df[1:].index, columns=df.columns)
    return shifted_df

# %%
temp_df = df.copy()
temp_df = shift_dates(temp_df)
temp_df.head()
# Out:
#              Open   High    Low  Close     Volume  Ex_Dividend  Split_Ratio  \
# Date
# 1980-12-15  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-16  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-17  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-18  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-19  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj_Open  Adj_High   Adj_Low  Adj_Close   Adj_Volume
# Date
# 1980-12-15  0.422706  0.424470  0.422706   0.422706  117258400.0
# 1980-12-16  0.402563  0.402563  0.400652   0.400652   43971200.0
# 1980-12-17  0.373010  0.373010  0.371246   0.371246   26432000.0
# 1980-12-18  0.380362  0.382273  0.380362   0.380362   21610400.0
# 1980-12-19  0.391536  0.393300  0.391536   0.391536   18362400.0

# %%
temp_df1 = temp_df.diff()
temp_df1.head(3)
# Out:
#             Open  High  Low  Close     Volume  Ex_Dividend  Split_Ratio  \
# Date
# 1980-12-15   NaN   NaN  NaN    NaN        NaN          NaN          NaN
# 1980-12-16 -1.37 -1.49 -1.5   -1.5 -1308700.0          0.0          0.0
# 1980-12-17 -2.01 -2.01 -2.0   -2.0  -313200.0          0.0          0.0
#
#             Adj_Open  Adj_High   Adj_Low         ...           Low_Long_EMA  \
# Date                                             ...
# 1980-12-15       NaN       NaN       NaN         ...                    NaN
# 1980-12-16 -0.020143 -0.021907 -0.022054         ...              -0.034884
# 1980-12-17 -0.029553 -0.029553 -0.029406         ...              -0.080584
#
#             Close_Long_EMA  Volume_Long_EMA  Ex_Dividend_Long_EMA  \
# Date
# 1980-12-15             NaN              NaN                   NaN
# 1980-12-16       -0.034884    -30434.883721                   0.0
# 1980-12-17       -0.080584    -37010.816658                   0.0
#
#             Split_Ratio_Long_EMA  Adj_Open_Long_EMA  Adj_High_Long_EMA  \
# Date
# 1980-12-15                   NaN                NaN                NaN
# 1980-12-16                   0.0          -0.000468          -0.000509
# 1980-12-17                   0.0          -0.001145          -0.001185
#
#             Adj_Low_Long_EMA  Adj_Close_Long_EMA  Adj_Volume_Long_EMA
# Date
# 1980-12-15               NaN                 NaN                  NaN
# 1980-12-16         -0.000513           -0.000513        -1.704353e+06
# 1980-12-17         -0.001185           -0.001185        -2.072606e+06
#
# [3 rows x 84 columns]

# %%
temp_df2 = temp_df.pct_change()
temp_df2.head(3)
# Out:
#                 Open      High       Low     Close    Volume  Ex_Dividend  \
# Date
# 1980-12-15       NaN       NaN       NaN       NaN       NaN          NaN
# 1980-12-16 -0.047652 -0.051611 -0.052174 -0.052174 -0.625006          NaN
# 1980-12-17 -0.073411 -0.073411 -0.073394 -0.073394 -0.398879          NaN
#
#             Split_Ratio  Adj_Open  Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Date
# 1980-12-15          NaN       NaN       NaN       NaN        NaN         NaN
# 1980-12-16          0.0 -0.047652 -0.051611 -0.052174  -0.052174   -0.625006
# 1980-12-17          0.0 -0.073411 -0.073411 -0.073394  -0.073394   -0.398879

# %%
def engineer_this(dataframe):
    """ 
    Returns a data frame with engineered moving averages.
    Two types of moving averages are calculated: Simple & Exponential. 
    Each type of moving average is calculated with a short (12-Day), medium (26-Day), and long (85-Day) lag.
   
    Parameters
    ---------------------------------------------------------------------------------------------------------
    dataframe : pd.DataFrame()
        Passes a dataframe.
    """
    
    temp_df = dataframe.copy()
    
    # Setting the Date as the Index and sorting in acsending order:
    temp_df.set_index('Date', inplace=True)
    temp_df.sort_index(inplace=True, ascending=True)
    
    # Calculating the Simple Moving Average:
    short_SMA = temp_df.rolling(window=12).mean().copy()
    mid_SMA = temp_df.rolling(window=26).mean().copy()
    long_SMA = temp_df.rolling(window=85).mean().copy()

    # Calculating the Exponential Moving Average:
    short_EMA = temp_df.ewm(span=12, adjust=False).mean().copy()
    mid_EMA = temp_df.ewm(span=26, adjust=False).mean().copy()
    long_EMA = temp_df.ewm(span=85, adjust=False).mean().copy()
    
    
    # Calcualting the Percent Change Per day
    pctChange = temp_df.pct_change()
    
    diffChange = temp_df.diff()
    
    temp_df = pd.merge(temp_df, pctChange, left_index=True, right_index=True, suffixes=['','_PCT_Change'])
    temp_df = pd.merge(temp_df, diffChange, left_index=True, right_index=True, suffixes=['','_Diff'])


#     MACD = short_EMA - mid_EMA
#     signal_line = MACD.ewm(span=9, adjust=False).mean().copy()
    
#     temp_df = pd.merge(temp_df, MACD, left_index=True, right_index=True, suffixes=['','_MACD'])
#     temp_df = pd.merge(temp_df, signal_line, left_index=True, right_index=True, suffixes=['','_Signal_Line'])
    
    # Merging the Simple Moving Avverages data frames with the original Data frame:
    temp_df = pd.merge(temp_df, short_SMA, left_index=True, right_index=True, suffixes=['','_Short_SMA'])
    temp_df = pd.merge(temp_df, mid_SMA, left_index=True, right_index=True, suffixes=['','_Mid_SMA'])
    temp_df = pd.merge(temp_df, long_SMA, left_index=True, right_index=True, suffixes=['','_Long_SMA'])
    
    # Merging the Exponential Moving Average data frames with the Original data frame:
    temp_df = pd.merge(temp_df, short_EMA, left_index=True, right_index=True, suffixes=['','_Short_EMA'])
    temp_df = pd.merge(temp_df, mid_EMA, left_index=True, right_index=True, suffixes=['','_Mid_EMA'])
    temp_df = pd.merge(temp_df, long_EMA, left_index=True, right_index=True, suffixes=['','_Long_EMA'])
    
    return temp_df

# %%
df = df.reset_index()

# %%
engineered_df = engineer_this(df).head()

# %%
# engineered_df.to_csv(f'../stocks/data/{company_name}_Engineered_pctChange.csv', index=False)

# %%
# temp_df['Date'] = pd.to_datetime(df.Date)
# temp_df.set_index('Date', inplace=True)
# temp_df.sort_index(inplace=True, ascending=True)

# %% [markdown]
# ## Taking a Look at the Time-Shifted Data Set:

# %%
df_shift.tail(3)
# Out:
#               Open    High     Low    Close      Volume  Ex_Dividend  \
# Date
# 2018-03-23  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-26  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-27  168.07  173.10  166.44  172.770  36272617.0          0.0
#
#             Split_Ratio  Adj_Open  Adj_High  Adj_Low         ...           \
# Date                                                         ...
# 2018-03-23          1.0    170.00    172.68   168.60         ...
# 2018-03-26          1.0    168.39    169.92   164.94         ...
# 2018-03-27          1.0    168.07    173.10   166.44         ...
#
#             Low_Long_EMA  Close_Long_EMA  Volume_Long_EMA  \
# Date
# 2018-03-23    169.691723      171.097703     3.358258e+07
# 2018-03-26    169.581218      170.954500     3.373761e+07
# 2018-03-27    169.508167      170.996721     3.379657e+07
#
#             Ex_Dividend_Long_EMA  Split_Ratio_Long_EMA  Adj_Open_Long_EMA  \
# Date
# 2018-03-23              0.000518                   1.0         171.126419
# 2018-03-26              0.000506                   1.0         171.062781
# 2018-03-27              0.000494                   1.0         170.993182
#
#             Adj_High_Long_EMA  Adj_Low_Long_EMA  Adj_Close_Long_EMA  \
# Date
# 2018-03-23         172.657153        169.671634          171.077463
# 2018-03-26         172.593499        169.561596          170.934731
# 2018-03-27         172.605278        169.489000          170.977412
#
#             Adj_Volume_Long_EMA
# Date
# 2018-03-23         3.358258e+07
# 2018-03-26         3.373761e+07
# 2018-03-27         3.379657e+07
#
# [3 rows x 84 columns]

# %% [markdown]
# ## Split the Data to Predict 2017+

# %%
df_shift[:'2017-01-03'].tail()
# Out:
#               Open      High     Low   Close      Volume  Ex_Dividend  \
# Date
# 2016-12-27  115.59  116.5200  115.59  116.52  14249484.0          0.0
# 2016-12-28  116.52  117.8000  116.49  117.26  18296855.0          0.0
# 2016-12-29  117.52  118.0166  116.20  116.76  20905892.0          0.0
# 2016-12-30  116.45  117.1095  116.40  116.73  15039519.0          0.0
# 2017-01-03  116.65  117.2000  115.43  115.82  30586265.0          0.0
#
#             Split_Ratio    Adj_Open    Adj_High     Adj_Low  \
# Date
# 2016-12-27          1.0  114.162295  115.080808  114.162295
# 2016-12-28          1.0  115.080808  116.344998  115.051178
# 2016-12-29          1.0  116.068456  116.558923  114.764760
# 2016-12-30          1.0  115.011672  115.663027  114.962290
# 2017-01-03          1.0  115.209202  115.752409  114.004271
#
#                    ...           Low_Long_EMA  Close_Long_EMA  \
# Date               ...
# 2016-12-27         ...             110.425003      111.333832
# 2016-12-28         ...             110.566050      111.471650
# 2016-12-29         ...             110.697072      111.594635
# 2016-12-30         ...             110.829698      111.714062
# 2017-01-03         ...             110.936682      111.809549
#
#             Volume_Long_EMA  Ex_Dividend_Long_EMA  Split_Ratio_Long_EMA  \
# Date
# 2016-12-27     3.374019e+07              0.007480                   1.0
# 2016-12-28     3.338105e+07              0.007306                   1.0
# 2016-12-29     3.309093e+07              0.007136                   1.0
# 2016-12-30     3.267113e+07              0.006970                   1.0
# 2017-01-03     3.262264e+07              0.006808                   1.0
#
#             Adj_Open_Long_EMA  Adj_High_Long_EMA  Adj_Low_Long_EMA  \
# Date
# 2016-12-27         109.439013         110.369718        108.756434
# 2016-12-28         109.570218         110.508678        108.902823
# 2016-12-29         109.721340         110.649382        109.039147
# 2016-12-30         109.844371         110.765978        109.176895
# 2017-01-03         109.969134         110.881942        109.289159
#
#             Adj_Close_Long_EMA  Adj_Volume_Long_EMA
# Date
# 2016-12-27          109.651716         3.374021e+07
# 2016-12-28          109.794971         3.338106e+07
# 2016-12-29          109.923409         3.309094e+07
# 2016-12-30          110.048172         3.267114e+07
# 2017-01-03          110.149132         3.262266e+07
#
# [5 rows x 84 columns]

# %%
df_shift['2017-01-03':].head()
# Out:
#               Open      High     Low   Close      Volume  Ex_Dividend  \
# Date
# 2017-01-03  116.65  117.2000  115.43  115.82  30586265.0          0.0
# 2017-01-04  115.80  116.3300  114.76  116.15  28781865.0          0.0
# 2017-01-05  115.85  116.5100  115.75  116.02  21118116.0          0.0
# 2017-01-06  115.92  116.8642  115.81  116.61  22193587.0          0.0
# 2017-01-09  116.78  118.1600  116.47  117.91  31751900.0          0.0
#
#             Split_Ratio    Adj_Open    Adj_High     Adj_Low  \
# Date
# 2017-01-03          1.0  115.209202  115.752409  114.004271
# 2017-01-04          1.0  114.369701  114.893155  113.342546
# 2017-01-05          1.0  114.419083  115.070931  114.320318
# 2017-01-06          1.0  114.488219  115.420756  114.379577
# 2017-01-09          1.0  115.337596  116.700551  115.031425
#
#                    ...           Low_Long_EMA  Close_Long_EMA  \
# Date               ...
# 2017-01-03         ...             110.936682      111.809549
# 2017-01-04         ...             111.025596      111.910490
# 2017-01-05         ...             111.135466      112.006060
# 2017-01-06         ...             111.244176      112.113128
# 2017-01-09         ...             111.365707      112.247939
#
#             Volume_Long_EMA  Ex_Dividend_Long_EMA  Split_Ratio_Long_EMA  \
# Date
# 2017-01-03     3.262264e+07              0.006808                   1.0
# 2017-01-04     3.253332e+07              0.006650                   1.0
# 2017-01-05     3.226785e+07              0.006495                   1.0
# 2017-01-06     3.203357e+07              0.006344                   1.0
# 2017-01-09     3.202702e+07              0.006197                   1.0
#
#             Adj_Open_Long_EMA  Adj_High_Long_EMA  Adj_Low_Long_EMA  \
# Date
# 2017-01-03         109.969134         110.881942        109.289159
# 2017-01-04         110.071473         110.975226        109.383424
# 2017-01-05         110.172580         111.070475        109.498236
# 2017-01-06         110.272944         111.171644        109.611755
# 2017-01-09         110.390726         111.300223        109.737794
#
#             Adj_Close_Long_EMA  Adj_Volume_Long_EMA
# Date
# 2017-01-03          110.149132         3.262266e+07
# 2017-01-04          110.255324         3.253334e+07
# 2017-01-05          110.356060         3.226787e+07
# 2017-01-06          110.468005         3.203358e+07
# 2017-01-09          110.607206         3.202703e+07
#
# [5 rows x 84 columns]

# %%
X_train, X_test = df_shift[:'2016-12-30'], df_shift['2017-01-03':]

# %%
df_shift = df_shift.apply(lambda x: x.astype(int))
df_shift.head()
# Out:
#             Open  High  Low  Close  Volume  Ex_Dividend  Split_Ratio  \
# Date
# 1981-04-15    27    28   27     27   29700            0            1
# 1981-04-16    26    26   26     26  152000            0            1
# 1981-04-20    25    25   25     25  106600            0            1
# 1981-04-21    25    25   25     25  157800            0            1
# 1981-04-22    27    27   27     27  127400            0            1
#
#             Adj_Open  Adj_High  Adj_Low         ...           Low_Long_EMA  \
# Date                                            ...
# 1981-04-15         0         0        0         ...                     27
# 1981-04-16         0         0        0         ...                     27
# 1981-04-20         0         0        0         ...                     27
# 1981-04-21         0         0        0         ...                     27
# 1981-04-22         0         0        0         ...                     27
#
#             Close_Long_EMA  Volume_Long_EMA  Ex_Dividend_Long_EMA  \
# Date
# 1981-04-15              27           395955                     0
# 1981-04-16              27           390282                     0
# 1981-04-20              27           383685                     0
# 1981-04-21              27           378432                     0
# 1981-04-22              27           372594                     0
#
#             Split_Ratio_Long_EMA  Adj_Open_Long_EMA  Adj_High_Long_EMA  \
# Date
# 1981-04-15                     1                  0                  0
# 1981-04-16                     1                  0                  0
# 1981-04-20                     1                  0                  0
# 1981-04-21                     1                  0                  0
# 1981-04-22                     1                  0                  0
#
#             Adj_Low_Long_EMA  Adj_Close_Long_EMA  Adj_Volume_Long_EMA
# Date
# 1981-04-15                 0                   0             22173534
# 1981-04-16                 0                   0             21855823
# 1981-04-20                 0                   0             21486376
# 1981-04-21                 0                   0             21192200
# 1981-04-22                 0                   0             20865275
#
# [5 rows x 84 columns]

# %% [markdown]
# ## Computing Average Uniqueness:

# %% [markdown]
# -----
#
# # Normalizing the Data with a MinMaxScaler
#
# ## Instantiating the Scaler:

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))

# %% [markdown]
# ## Scaling the Training Set:

# %%
X_train_sc = scaler.fit_transform(X_train.values)

# %% [markdown]
# ## Scaling the Testing Set:

# %%
X_test_sc = scaler.transform(X_test.values)

# %% [markdown]
# ## Setting the y Training Set:

# %%
y_train = df[X_train.index[0]:X_train.index[-1]].Close.values

# %% [markdown]
# ## Setting the y Testing Set

# %%
y_test = df[X_test.index[0]:X_test.index[-1]].Close.values

# %% [markdown]
# -----
#
# # Random Forest Classification Model
#
# ## Setting up the Random Forest (RF) Classification:

# %%
rf = RandomForestClassifier(n_estimators=100, criterion='entropy', 
                            max_depth=15, min_samples_leaf=3, bootstrap=True, 
                            n_jobs=3, random_state=42, class_weight='balanced_subsample')

# %%
bc = BaggingClassifier(base_estimator=rf, n_estimators=100, max_samples=7.02, 
                   max_features=1.0, n_jobs=3, random_state=42)

# %% [markdown]
# ### Fitting the Scaled Data with the RF Model:

# %%
bc.fit(X_train_sc, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-58cb074b6693> in <module>()
# ----> 1 bc.fit(X_train_sc, y_train)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/sklearn/ensemble/bagging.py in fit(self, X, y, sample_weight)
#     245             Returns self.
#     246         """
# --> 247         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     248
#     249     def _fit(self, X, y, max_samples=None, max_depth=None, sample_weight=None):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/sklearn/ensemble/bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     289         n_samples, self.n_features_ = X.shape
#     290         self._n_samples = n_samples
# --> 291         y = self._validate_y(y)
#     292
#     293         # Check parameters
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/sklearn/ensemble/bagging.py in _validate_y(self, y)
#     616     def _validate_y(self, y):
#     617         y = column_or_1d(y, warn=True)
# --> 618         check_classification_targets(y)
#     619         self.classes_, y = np.unique(y, return_inverse=True)
#     620         self.n_classes_ = len(self.classes_)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# ### Scoring on the Training Data:

# %%
bc.score(X_train_sc, y_train)

# %% [markdown]
# ### Scoring on the Testing Data

# %%
bc.score(X_test_sc, y_test)

# %% [markdown]
# ### Inspecting the Average Prediction:

# %%
y_test.mean()

# %%
bc.predict(X_test_sc).mean()

# %%
error.error

# %% [markdown]
# -----
#
# # Grid Searching a Random Forest Regression Model:

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Creating a Pipeline

# %%
pipe = Pipeline([
    ('rf', RandomForestRegressor())
])

# %% [markdown]
# ### Setting up the Parameters:

# %%
np.linspace(40, 100, 5)

# %%
# Number of trees in random forest

n_estimators = [int(x) for x in np.linspace(start = 40, stop = 100, num = 5)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(2, 80, 2)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
params = {'rf__n_estimators': n_estimators,
           'rf__max_features': max_features,
           'rf__max_depth': max_depth,
           'rf__min_samples_split': min_samples_split,
           'rf__min_samples_leaf': min_samples_leaf,
           'rf__bootstrap': bootstrap}
print(params)

# %% [markdown]
# ### Gridsearching the Parameters:

# %%
rf_search = GridSearchCV(pipe, params, n_jobs=3)

# %% [markdown]
# ### Fitting the Scaled Data with the Model:

# %%
rf_search.fit(X_train_sc, y_train)

# %% [markdown]
# ### Scoring the Training Data:

# %%
rf_search.score(X_train_sc, y_train)

# %% [markdown]
# ### Scoring the Test Data

# %%
rf_search.score(X_test_sc, y_test)

# %%
plt.scatter(y_test, rf_search.predict(X_test_sc))
plt.xlabel('Actual')
plt.ylabel('Predicted')

# %% [markdown]
# - `'rf__n_estimators': [40, 55, 70, 85, 100],` => `n_estimators=10, `
#
#
# - `'rf__max_features': ['auto', 'sqrt'],` => `max_features='auto',`
#
#
# - `'rf__max_depth': [2, 80, None],` => -`max_depth=None,`
#
#
# - `'rf__min_samples_split': [2, 5, 10],` => `min_samples_split=2,`
#
#
# - `'rf__min_samples_leaf': [1, 2, 4],` => `min_samples_leaf=1,`
#
#
# - `'rf__bootstrap': [True, False]` => `bootstrap=True,`

# %% [markdown]
# --------
#
# ## GridSearching a Random Forest with Weights:

# %%
pipe_w = Pipeline([
    ('pca', PCA()),
    ('rf', RandomForestRegressor())
])

# %% [markdown]
# ### Setting the Params

# %%
# Number of trees in random forest
n_estimators_w = [x for x in range(6, 16, 2)]

# Number of features to consider at every split
max_features_w = ['auto', 'log2']

# Maximum number of levels in tree
max_depth_w = [x for x in range(1, 5)]
max_depth_w.append(None)

# Minimum number of samples required to split a node
min_samples_split_w = [x for x in range(1, 5)]

# Minimum number of samples required at each leaf node
min_samples_leaf_w = [x for x in range(1, 5)]

# Method of selecting samples for training each tree
bootstrap_w = [True, False]

pca_n_components= [x for x in range(2, 24, 4)]

pca_svd_solver = ['auto', 'full', 'arpack', 'randomized']

# %% [markdown]
# ### Setting up the Parameters with PCA Weights:

# %%
params_w = {'rf__n_estimators': n_estimators_w,
          'rf__max_features': max_features_w,
          'rf__max_depth': max_depth_w,
          'rf__min_samples_split': min_samples_split_w,
          'rf__min_samples_leaf': min_samples_leaf_w,
          'rf__bootstrap': bootstrap_w}
print(params_w)

# %% [markdown]
# ### Gridsearching the Parameters with PCA:

# %%
grid = GridSearchCV(pipe_w, params_w, n_jobs=3)

# %% [markdown]
# ### Fitting the Scaled Data with a Weighted Model:

# %%
grid.fit(X_train_sc, y_train)

# %% [markdown]
# ### Scoring the Training Data:

# %%
grid.score(X_train_sc, y_train)

# %% [markdown]
# ### Scoring the Test Data:

# %%
grid.score(X_test_sc, y_test)

# %%
plt.scatter(y_test, grid.predict(X_test_sc))
plt.xlabel('Actual')
plt.ylabel('Predicted')

# %% [markdown]
# ----
#
# # Modeling

# %% [markdown]
# ## Attempting a Simple Linear Regression Model:

# %%
# from sklearn.linear_model import LinearRegression

# %%
# lr = LinearRegression()

# %%
# lr.fit(X_train_sc, y_train)

# %%
# lr.score(X_train_sc, y_train)

# %%
# lr.score(X_test_sc, y_test)

# %%
# plt.scatter(y_test, lr.predict(X_test_sc))
# plt.xlabel('Actual')
# plt.ylabel('Predicted')

# %%
# coef_weights = pd.DataFrame(lr.coef_, index=X_train.columns, columns=['weight'])

# %%
# coef_weights.sort_values('weight').tail()

# %% [markdown]
# # Time Series Split
#
# `TimeSeriesSplit(n_splits=3, max_train_size=None)`
#
# A Time Series cross-validator providing both a train and test index to split time series data observed at fixed time intervals. During each split, the test indices must be higher (in time) than before; therefore, random shuffling is inappropriate.
#
# A variation of K-Fold; in the $Kth$ split, the model returns the first $K$ folds as train set and the $(k+1)th$ fold as test set. However, unlike the standard cross-validation methods, successive training sets are supersets of those that come before them.

# %% [markdown]
# ## Scaling the Data
#
# ### Fitting and Transforming the Training Set:

# %%
# X_train_scaled = scaler.fit_transform(X.values)

# %% [markdown]
# ### Checking the Shape:

# %%
# X_train_scaled.shape

# %%
# X_train_scaled

# %% [markdown]
# ### Transforming the Prediction Label:

# %%
# X_test_transformed = scaler.transform(test.values)

# %% [markdown]
# ### Checking the Shape:

# %%
# X_test_transformed.shape

# %%
# X_test_transformed

# %% [markdown]
# ## Splitting the Data using TimeSeriesSplit:

# %%
# tss = TimeSeriesSplit()  

# for train_index, test_index in tss.split(X_train_sc):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X_train_sc[train_index], X_train_sc[test_index]
#     y_train, y_test = X_train_sc[train_index], X_train_sc[test_index]

### Inspecting the Shape:

# %%
# for train_index, test_index in tss.split(X_train_sc):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X_train_sc[train_index], X_train_sc[test_index]
#     y_train, y_test = X_train_sc[train_index], X_train_sc[test_index]

### Inspecting the Shape:

# %% [markdown]
# ### Inspecting the Shape:

# %%
# print('Shapes: ', '\n'
#     'X_train: ', X_train.shape, '\n'
#      'X_test: ', X_test.shape, '\n'
#       '\n'
#      'y_train: ',y_train.shape, '\n'
#       'y_test: ', y_test.shape)
